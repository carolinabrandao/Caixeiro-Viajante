# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('results.csv')

# %%
#count the number of times each algorithm was used
print(df['Algoritmo'].value_counts())
# Out:
# Algoritmo
# Twice Around the Tree    73
# Christofides             70
# Name: count, dtype: int64

# %%
#menor e maior qualidade de solucao dos dois algoritmos junto com o numero de nós equivalente
print(df.groupby(['Algoritmo'])['Qualidade'].min())
print(df.groupby(['Algoritmo'])['Qualidade'].max())
# Out:
# Algoritmo
# Christofides             1.053725
# Twice Around the Tree    1.168926
# Name: Qualidade, dtype: float64
# Algoritmo
# Christofides             1.202748
# Twice Around the Tree    1.569811
# Name: Qualidade, dtype: float64

# %%
twice_around_tree = df[df['Algoritmo'] == 'Twice Around the Tree']
christofides = df[df['Algoritmo'] == 'Christofides']

# Configuração do gráfico
plt.figure(figsize=(10, 6))

# Plotar os dados para Twice Around the Tree com linha
plt.plot(twice_around_tree['Nós'], twice_around_tree['Qualidade'], label='Twice Around the Tree', marker='o')

# Plotar os dados para Christofides com linha
plt.plot(christofides['Nós'], christofides['Qualidade'], label='Christofides', marker='x')

# Adicionar rótulos e título
plt.xlabel('Número de Nós')
plt.ylabel('Qualidade')
plt.title('Qualidade dos Algoritmos para Diferentes Números de Nós')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Leitura do CSV
df = pd.read_csv('results.csv')

# Filtrar os dados para Twice Around the Tree e Christofides
twice_around_tree = df[df['Algoritmo'] == 'Twice Around the Tree']
christofides = df[df['Algoritmo'] == 'Christofides']

# Configuração do gráfico
plt.figure(figsize=(10, 6))

# Plotar os dados para Twice Around the Tree com linha
plt.plot(twice_around_tree['Nós'], twice_around_tree['Tempo de execução(s)'], label='Twice Around the Tree', marker='o')

# Plotar os dados para Christofides com linha
plt.plot(christofides['Nós'], christofides['Tempo de execução(s)'], label='Christofides', marker='x')

# Adicionar rótulos e título
plt.xlabel('Número de Nós')
plt.ylabel('Tempo de Execução (s)')
plt.title('Tempo de Execução em Função do Número de Nós')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Leitura do CSV
df = pd.read_csv('results.csv')

# Filtrar os dados para Twice Around the Tree e Christofides
twice_around_tree = df[df['Algoritmo'] == 'Twice Around the Tree']
christofides = df[df['Algoritmo'] == 'Christofides']

# Configuração do gráfico
plt.figure(figsize=(10, 6))


# Plotar os dados para Christofides com linha
plt.plot(christofides['Nós'], christofides['Tempo de execução(s)'], label='Christofides', marker='x')

# Adicionar rótulos e título
plt.xlabel('Número de Nós')
plt.ylabel('Tempo de Execução (s)')
plt.title('Tempo de Execução em Função do Número de Nós')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Leitura do CSV
df = pd.read_csv('results.csv')

# Filtrar os dados para Twice Around the Tree e Christofides
twice_around_tree = df[df['Algoritmo'] == 'Twice Around the Tree']
christofides = df[df['Algoritmo'] == 'Christofides']

# Configuração do gráfico
plt.figure(figsize=(10, 6))

# Plotar os dados para Twice Around the Tree com linha
plt.plot(twice_around_tree['Nós'], twice_around_tree['Memória(bytes)'], label='Twice Around the Tree', marker='o')

# Plotar os dados para Christofides com linha
plt.plot(christofides['Nós'], christofides['Memória(bytes)'], label='Christofides', marker='x')

# Adicionar rótulos e título
plt.xlabel('Número de Nós')
plt.ylabel('Memória (bytes)')
plt.title('Consumo de Memória em Função do Número de Nós')
plt.legend()  # Adicionar legenda

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
#maior tempo de execução do christofides
print(df.loc[df.groupby(['Algoritmo'])['Tempo de execução(s)'].idxmax()])
# Out:
#     Instância              Algoritmo   Nós    Limiar      Resultado
# 137   pcb3038           Christofides  3038  137694.0  154218.185880  \
# 142    rl5934  Twice Around the Tree  5934  555057.5  827482.336028
#
#      Qualidade  Tempo de execução(s)  Memória(bytes)
# 137   1.120007           1418.174607      1590859302
# 142   1.490805            158.225954      5417719137
